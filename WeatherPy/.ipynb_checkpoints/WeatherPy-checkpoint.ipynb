# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 590

# %%
#cities

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
# https://api.openweathermap.org/data/2.5/weather?q={city name}&appid={API key}
url = "https://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
city_name = "city"

city_url = url + "&appid=" + weather_api_key + "&q=" + city_name + "&units=" + units

# %%
requests.get(city_url).json()
# response =requests.get(city_url).json()
# response
# Out:
# {'coord': {'lon': 149.1292, 'lat': -35.2813},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 51.76,
#   'feels_like': 50.92,
#   'temp_min': 49.08,
#   'temp_max': 54.28,
#   'pressure': 1023,
#   'humidity': 91},
#  'visibility': 10000,
#  'wind': {'speed': 8.05, 'deg': 180},
#  'clouds': {'all': 100},
#  'dt': 1714842633,
#  'sys': {'type': 2,
#   'id': 2004200,
#   'country': 'AU',
#   'sunrise': 1714855408,
#   'sunset': 1714893410},
#  'timezone': 36000,
#  'id': 2172517,
#  'name': 'City',
#  'cod': 200}

# %%
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&appid=" + weather_api_key + "&q=" + city_name + "&units=" + units
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json() #cit_weather = response in class examples
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})      

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dudinka
# Processing Record 2 of Set 1 | port mathurin
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | aasiaat
# Processing Record 5 of Set 1 | den burg
# Processing Record 6 of Set 1 | akureyri
# Processing Record 7 of Set 1 | waitangi
# Processing Record 8 of Set 1 | vilyuchinsk
# Processing Record 9 of Set 1 | carnarvon
# Processing Record 10 of Set 1 | zonguldak
# Processing Record 11 of Set 1 | la'ie
# Processing Record 12 of Set 1 | devinuwara
# Processing Record 13 of Set 1 | the bottom
# Processing Record 14 of Set 1 | grytviken
# Processing Record 15 of Set 1 | adamstown
# Processing Record 16 of Set 1 | ola
# Processing Record 17 of Set 1 | qaqortoq
# Processing Record 18 of Set 1 | oranjemund
# Processing Record 19 of Set 1 | bayanhongor
# Processing Record 20 of Set 1 | guerrero negro
# Processing Record 21 of Set 1 | isafjordur
# Processing Record 22 of Set 1 | margaret river
# Processing Record 23 of Set 1 | skelleftea
# Processing Record 24 of Set 1 | claremore
# Processing Record 25 of Set 1 | sinabang
# Processing Record 26 of Set 1 | bethel
# Processing Record 27 of Set 1 | kapa'a
# Processing Record 28 of Set 1 | kodiak
# Processing Record 29 of Set 1 | arys
# Processing Record 30 of Set 1 | wailua homesteads
# Processing Record 31 of Set 1 | kindu
# Processing Record 32 of Set 1 | coahuayana de hidalgo
# Processing Record 33 of Set 1 | puerto natales
# Processing Record 34 of Set 1 | kasongo-lunda
# Processing Record 35 of Set 1 | georgetown
# Processing Record 36 of Set 1 | hailey
# Processing Record 37 of Set 1 | la ronge
# Processing Record 38 of Set 1 | enewetak
# Processing Record 39 of Set 1 | corowa
# Processing Record 40 of Set 1 | dalbandin
# Processing Record 41 of Set 1 | port-aux-francais
# Processing Record 42 of Set 1 | ahau
# Processing Record 43 of Set 1 | kone
# Processing Record 44 of Set 1 | codrington
# Processing Record 45 of Set 1 | tsiombe
# Processing Record 46 of Set 1 | yellowknife
# Processing Record 47 of Set 1 | ribeira grande
# Processing Record 48 of Set 1 | longyearbyen
# Processing Record 49 of Set 1 | college
# Processing Record 50 of Set 1 | hamilton
# Processing Record 0 of Set 2 | dhar
# Processing Record 1 of Set 2 | sao gabriel da cachoeira
# Processing Record 2 of Set 2 | teknaf
# Processing Record 3 of Set 2 | sabha
# Processing Record 4 of Set 2 | kathmandu
# Processing Record 5 of Set 2 | vorgashor
# Processing Record 6 of Set 2 | blackmans bay
# Processing Record 7 of Set 2 | margate
# Processing Record 8 of Set 2 | stanley
# Processing Record 9 of Set 2 | ar rutbah
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | lihue
# Processing Record 12 of Set 2 | puerto deseado
# Processing Record 13 of Set 2 | avarua
# Processing Record 14 of Set 2 | keflavik
# Processing Record 15 of Set 2 | bilibino
# Processing Record 16 of Set 2 | panaba
# Processing Record 17 of Set 2 | dwarka
# Processing Record 18 of Set 2 | alofi
# Processing Record 19 of Set 2 | bhag
# Processing Record 20 of Set 2 | pangody
# Processing Record 21 of Set 2 | tazovsky
# Processing Record 22 of Set 2 | wakkanai
# Processing Record 23 of Set 2 | west island
# Processing Record 24 of Set 2 | port elizabeth
# Processing Record 25 of Set 2 
# Processing Record 9 of Set 4 | sitka
# Processing Record 10 of Set 4 | remire-montjoly
# Processing Record 11 of Set 4 | mossel bay
# Processing Record 12 of Set 4 | yangor
# Processing Record 13 of Set 4 | bayan nur
# Processing Record 14 of Set 4 | awjilah
# Processing Record 15 of Set 4 | tolanaro
# Processing Record 16 of Set 4 | simanggang
# Processing Record 17 of Set 4 | talcahuano
# Processing Record 18 of Set 4 | puerto ayora
# Processing Record 19 of Set 4 | new norfolk
# Processing Record 20 of Set 4 | pacocha
# Processing Record 21 of Set 4 | kalix
# Processing Record 22 of Set 4 | dampit
# Processing Record 23 of Set 4 | ilha de mocambique
# Processing Record 24 of Set 4 | alotau
# Processing Record 25 of Set 4 | touros
# Processing Record 26 of Set 4 | hasaki
# Processing Record 27 of Set 4 | metu
# Processing Record 28 of Set 4 | enkhuizen
# Processing Record 29 of Set 4 | utrik
# Processing Record 30 of Set 4 | bangaon
# Processing Record 31 of Set 4 | saint-philippe
# Processing Record 32 of Set 4 | yauya
# Processing Record 33 of Set 4 | berezovyy
# Processing Record 34 of Set 4 | xinyu
# Processing Record 35 of Set 4 | udachny
# Processing Record 36 of Set 4 | kapuskasing
# Processing Record 37 of Set 4 | uturoa
# Processing Record 38 of Set 4 | port alfred
# Processing Record 39 of Set 4 | purpe
# Processing Record 40 of Set 4 | crane
# Processing Record 41 of Set 4 | phalaborwa
# Processing Record 42 of Set 4 | kalabo
# Processing Record 43 of Set 4 | polgardi
# Processing Record 44 of Set 4 | kamloops
# Processing Record 45 of Set 4 | tomatlan
# Processing Record 46 of Set 4 | turbat
# Processing Record 47 of Set 4 | lebu
# Processing Record 48 of Set 4 | fortuna
# Processing Record 49 of Set 4 | am timan
# Processing Record 0 of Set 5 | callao
# Processing Record 1 of Set 5 | saipan
# Processing Record 2 of Set 5 | malango
# Processing Record 3 of Set 5 | kosh-agach
# Processing Record 4 of Set 5 | camapua
# Processing Record 5 of Set 5 | quellon
# Processing Record 6 of Set 5 | tanjungtiram
# Processing Record 7 of Set 5 | omidiyeh
# Processing Record 8 of Set 5 | chonchi
# Processing Record 9 of Set 5 | faya-largeau
# Processing Record 10 of Set 5 | praia da vitoria
# Processing Record 11 of Set 5 | ladang seri kundang
# Processing Record 12 of Set 5 | colares
# Processing Record 13 of Set 5 | sola
# Processing Record 14 of Set 5 | calderitas
# Processing Record 15 of Set 5 | pisco
# Processing Record 16 of Set 5 | mount isa
# Processing Record 17 of Set 5 | pariaman
# Processing Record 18 of Set 5 | okhotsk
# Processing Record 19 of Set 5 | chernomorskoye
# Processing Record 20 of Set 5 | hermanus
# Processing Record 21 of Set 5 | isle of lewis
# Processing Record 22 of Set 5 | jiangyou
# Processing Record 23 of Set 5 | broome
# Processing Record 24 of Set 5 | bambanglipuro
# Processing Record 25 of Set 5 | tongging
# Processing Record 26 of Set 5 | lincheng
# Processing Record 27 of Set 5 | meadville
# Processing Record 28 of Set 5 | kruisfontein
# Processing Record 29 of Set 5 | fuwwah
# Processing Record 30 of Set 5 | quiruvilca
# Processing Record 31 of Set 5 | tekane
# Processing Record 32 of Set 5 | villa regina
# Processing Record 33 of Set 5 | ardakan
# Processing Record 34 of Set 5 | zuyevka
# Processing Record 35 of Set 5 | eastbourne
# Processing Record 36 of Set 5 | geraldton
# Processing Record 37 of Set 5 | suances
# Processing Record 38 of Set 5 | naracoorte
# Processing Record 39 of Set 5 | pechora
# Processing Record 40 of Set 5 | pyhajarvi
# Processing Record 41 of Set 5 | carutapera
# Processing Record 42 of Set 5 | gadzhiyevo
# Processing Record 43 of Set 5 | sale
# Processing Record 44 of Set 5 | nabire
# Processing Record 45 of Set 5 | inhambane
# Processing Record 46 of Set 5 | les avirons
# Processing Record 47 of Set 5 | jebba
# Processing Record 48 of Set 5 | kingston
# Processing Record 49 of Set 5 | belomorsk
# Processing Record 0 of Set 6 | princeville
# Processing Record 1 of Set 6 | bambari
# Processing Record 2 of Set 6 | lichinga
# Processing Record 3 of Set 6 | bardai
# Processing Record 4 of Set 6 | la passe
# Processing Record 5 of Set 6 | kununurra
# Processing Record 6 of Set 6 | hun
# Processing Record 7 of Set 6 | huarmey
# Processing Record 8 of Set 6 | cibitoke
# Processing Record 9 of Set 6 | russellville
# Processing Record 10 of Set 6 | leshan
# Processing Record 11 of Set 6 | san borja
# Processing Record 12 of Set 6 | polyarnyy
# Processing Record 13 of Set 6 | cidreira
# Processing Record 14 of Set 6 | santa isabel
# Processing Record 15 of Set 6 | sicuani
# Processing Record 16 of Set 6 | nar'yan-mar
# Processing Record 17 of Set 6 | maintirano
# Processing Record 18 of Set 6 | kandahar
# Processing Record 19 of Set 6 | road town
# Processing Record 20 of Set 6 | fort mcmurray
# Processing Record 21 of Set 6 | hithadhoo
# Processing Record 22 of Set 6 | craig
# Processing Record 23 of Set 6 | cockburn town
# Processing Record 24 of Set 6 | lompoc
# Processing Record 25 of Set 6 | parabel'
# Processing Record 26 of Set 6 | tataouine
# Processing Record 27 of Set 6 | ostersund
# Processing Record 28 of Set 6 | saint-joseph
# Processing Record 29 of Set 6 | kasumkent
# Processing Record 30 of Set 6 | abnub
# Processing Record 31 of Set 6 | mezhdurechenskiy
# Processing Record 32 of Set 6 | selfoss
# Processing Record 33 of Set 6 | tshikapa
# Processing Record 34 of Set 6 | sabzevar
# Processing Record 35 of Set 6 | whitehorse
# Processing Record 36 of Set 6 | duncan town
# Processing Record 37 of Set 6 | mpanda
# Processing Record 38 of Set 6 | nueva gerona
# Processing Record 39 of Set 6 | nova sintra
# Processing Record 40 of Set 6 | new plymouth
# Processing Record 41 of Set 6 | kargopol'
# Processing Record 42 of Set 6 | casper
# Processing Record 43 of Set 6 | wewak
# Processing Record 44 of Set 6 | grand baie
# Processing Record 45 of Set 6 | koryazhma
# Processing Record 46 of Set 6 | ugoofaaru
# Processing Record 47 of Set 6 | kamen'-na-obi
# Processing Record 48 of Set 6 | arraial do cabo
# Processing Record 49 of Set 6 | champerico
# Processing Record 0 of Set 7 | lerma
# Processing Record 1 of Set 7 | dalandzadgad
# Processing Record 2 of Set 7 | urzhar
# Processing Record 3 of Set 7 | buchanan
# Processing Record 4 of Set 7 | kamennomostskiy
# Processing Record 5 of Set 7 | isiro
# Processing Record 6 of Set 7 | yankton
# Processing Record 7 of Set 7 | santiago de cao
# Processing Record 8 of Set 7 | ancud
# Processing Record 9 of Set 7 | nikolayevsk-on-amure
# Processing Record 10 of Set 7 | pacific grove
# Processing Record 11 of Set 7 | lata
# Processing Record 12 of Set 7 | pandan
# Processing Record 13 of Set 7 | namibe
# Processing Record 14 of Set 7 
# Processing Record 46 of Set 8 | el calafate
# Processing Record 47 of Set 8 | hengchun
# Processing Record 48 of Set 8 | luderitz
# Processing Record 49 of Set 8 | axim
# Processing Record 0 of Set 9 | porteirinha
# Processing Record 1 of Set 9 | lazaro cardenas
# Processing Record 2 of Set 9 | taoudenni
# Processing Record 3 of Set 9 | banfora
# Processing Record 4 of Set 9 | chegdomyn
# Processing Record 5 of Set 9 | gulf shores
# Processing Record 6 of Set 9 | caleta de carquin
# Processing Record 7 of Set 9 | mocorito
# Processing Record 8 of Set 9 | dryden
# Processing Record 9 of Set 9 | steamboat springs
# Processing Record 10 of Set 9 | mejit
# Processing Record 11 of Set 9 | cruz grande
# Processing Record 12 of Set 9 | loiza
# Processing Record 13 of Set 9 | flekkefjord
# Processing Record 14 of Set 9 | conception bay south
# Processing Record 15 of Set 9 | noumea
# Processing Record 16 of Set 9 | beloyarskiy
# Processing Record 17 of Set 9 | antsiranana
# Processing Record 18 of Set 9 | katsuura
# Processing Record 19 of Set 9 | machico
# Processing Record 20 of Set 9 | vernon
# Processing Record 21 of Set 9 | udon thani
# Processing Record 22 of Set 9 | arno
# Processing Record 23 of Set 9 | dongsheng
# Processing Record 24 of Set 9 | kota tinggi
# Processing Record 25 of Set 9 | walvis bay
# Processing Record 26 of Set 9 | rio grande
# Processing Record 27 of Set 9 | moyynkum
# Processing Record 28 of Set 9 | lillehammer
# Processing Record 29 of Set 9 | santana do livramento
# Processing Record 30 of Set 9 | tyukhtet
# Processing Record 31 of Set 9 | hastings
# Processing Record 32 of Set 9 | kyaikkami
# Processing Record 33 of Set 9 | haapavesi
# Processing Record 34 of Set 9 | bubaque
# Processing Record 35 of Set 9 | smithers
# Processing Record 36 of Set 9 | oliva
# Processing Record 37 of Set 9 | toga village
# Processing Record 38 of Set 9 | madalena
# Processing Record 39 of Set 9 | bodaybo
# Processing Record 40 of Set 9 | richards bay
# Processing Record 41 of Set 9 | lib
# Processing Record 42 of Set 9 | gereida
# Processing Record 43 of Set 9 | roma
# Processing Record 44 of Set 9 | mount pearl
# Processing Record 45 of Set 9 | shendi
# Processing Record 46 of Set 9 | mahajanga
# Processing Record 47 of Set 9 | gargalianoi
# Processing Record 48 of Set 9 | benguela
# Processing Record 49 of Set 9 | cable beach
# Processing Record 0 of Set 10 | calliope
# Processing Record 1 of Set 10 | ratne
# Processing Record 2 of Set 10 | barranca
# Processing Record 3 of Set 10 | primero de mayo
# Processing Record 4 of Set 10 | auki
# Processing Record 5 of Set 10 | yuktae-dong
# Processing Record 6 of Set 10 | palikir - national government center
# Processing Record 7 of Set 10 | east london
# Processing Record 8 of Set 10 | puerto quijarro
# Processing Record 9 of Set 10 | malanje
# Processing Record 10 of Set 10 | khovd
# Processing Record 11 of Set 10 | holualoa
# Processing Record 12 of Set 10 | jutai
# Processing Record 13 of Set 10 | oppdal
# Processing Record 14 of Set 10 | bontang
# Processing Record 15 of Set 10 | cumana
# Processing Record 16 of Set 10 | lakota
# Processing Record 17 of Set 10 | port lincoln
# Processing Record 18 of Set 10 | port blair
# Processing Record 19 of Set 10 | ceerigaabo
# Processing Record 20 of Set 10 | wynyard
# Processing Record 21 of Set 10 | tabou
# Processing Record 22 of Set 10 | rabaul
# Processing Record 23 of Set 10 | fuyu
# Processing Record 24 of Set 10 | sarandi grande
# Processing Record 25 of Set 10 | mandalgovi
# Processing Record 26 of Set 10 | halifax
# Processing Record 27 of Set 10 | takoradi
# Processing Record 28 of Set 10 | al bawiti
# Processing Record 29 of Set 10 | lengshuitan
# Processing Record 30 of Set 10 | neverkino
# Processing Record 31 of Set 10 | bel ombre
# Processing Record 32 of Set 10 | ugbokpo
# Processing Record 33 of Set 10 | ulsteinvik
# Processing Record 34 of Set 10 | kavaratti
# Processing Record 35 of Set 10 | qulsary
# Processing Record 36 of Set 10 | gaillimh
# Processing Record 37 of Set 10 | chibougamau
# Processing Record 38 of Set 10 | alaghsas
# Processing Record 39 of Set 10 | airuk
# Processing Record 40 of Set 10 | tazacorte
# Processing Record 41 of Set 10 | karwar
# Processing Record 42 of Set 10 | hilo
# Processing Record 43 of Set 10 | saedinenie
# Processing Record 44 of Set 10 | thames
# Processing Record 45 of Set 10 | toliara
# Processing Record 46 of Set 10 | balabac
# Processing Record 47 of Set 10 | nibaliw central
# Processing Record 48 of Set 10 | indianola
# Processing Record 49 of Set 10 | ratnagiri
# Processing Record 0 of Set 11 | puerto cabezas
# Processing Record 1 of Set 11 | ocotlan de morelos
# Processing Record 2 of Set 11 | wanparti
# Processing Record 3 of Set 11 | bafq
# Processing Record 4 of Set 11 | bandon
# Processing Record 5 of Set 11 | tobelo
# Processing Record 6 of Set 11 | tanjung pinang
# Processing Record 7 of Set 11 | fale old settlement
# Processing Record 8 of Set 11 | kumla
# Processing Record 9 of Set 11 | san antonio del estrecho
# Processing Record 10 of Set 11 | decorah
# Processing Record 11 of Set 11 | rongelap
# Processing Record 12 of Set 11 | ballsh
# Processing Record 13 of Set 11 | sishilichengzi
# Processing Record 14 of Set 11 | cole harbour
# Processing Record 15 of Set 11 | tchintabaraden
# Processing Record 16 of Set 11 | bozdar wada
# Processing Record 17 of Set 11 | embi
# Processing Record 18 of Set 11 | aldinga beach
# Processing Record 19 of Set 11 | shevchenko
# Processing Record 20 of Set 11 | ascencion
# Processing Record 21 of Set 11 | torit
# Processing Record 22 of Set 11 | essaouira
# Processing Record 23 of Set 11 | mahina
# Processing Record 24 of Set 11 | yaren
# Processing Record 25 of Set 11 | orkney
# Processing Record 26 of Set 11 | wajir
# Processing Record 27 of Set 11 | qamdo
# Processing Record 28 of Set 11 | lautoka
# Processing Record 29 of Set 11 | eraan
# Processing Record 30 of Set 11 | fort st. john
# Processing Record 31 of Set 11 | jiagedaqi
# Processing Record 32 of Set 11 | kljuc
# Processing Record 33 of Set 11 | shawinigan
# Processing Record 34 of Set 11 | yeniseysk
# Processing Record 35 of Set 11 | island harbour
# Processing Record 36 of Set 11 | almeirim
# Processing Record 37 of Set 11 | lodi
# Processing Record 38 of Set 11 | lucaya
# Processing Record 39 of Set 11 | manokwari
# Processing Record 40 of Set 11 | miquelon
# Processing Record 41 of Set 11 | vingt cinq
# Processing Record 42 of Set 11 | preobrazheniye
# Processing Record 43 of Set 11 | asau village
# Processing Record 44 of Set 11 | san patricio
# Processing Record 45 of Set 11 | pimenta bueno
# Processing Record 46 of Set 11 | nicoya
# Processing Record 47 of Set 11 | susanville
# Processing Record 48 of Set 11 | maloyaroslavets
# Processing Record 49 of Set 11 | port augusta
# Processing Record 0 of Set 12 | sant feliu de guixols
# Processing Record 1 of Set 12 | hurricane
# Processing Record 2 of Set 12 | novokazalinsk
# Processing Record 3 of Set 12 | suai
# Processing Record 4 of Set 12 | tynda
# Processing Record 5 of Set 12 | ertil'
# Processing Record 6 of Set 12 | dhuusamarreeb
# Processing Record 7 of Set 12 | chimore
# Processing Record 8 of Set 12 | taupo
# Processing Record 9 of Set 12 | peniche
# Processing Record 10 of Set 12 | yampil'
# Processing Record 11 of Set 12 | alta
# Processing Record 12 of Set 12 | posadas
# Processing Record 13 of Set 12 | opuwo
# Processing Record 14 of Set 12 | norilsk
# Processing Record 15 of Set 12 | murud
# Processing Record 16 of Set 12 | bocanda
# Processing Record 17 of Set 12 | howrah
# Processing Record 18 of Set 12 | jiujiang
# Processing Record 19 of Set 12 | brisas de zicatela
# Processing Record 20 of Set 12 | tralee
# Processing Record 21 of Set 12 | ibirataia
# Processing Record 22 of Set 12 | raton
# Processing Record 23 of Set 12 | richmond
# Processing Record 24 of Set 12 | sechura
# Processing Record 25 of Set 12 | ciudad lazaro cardenas
# Processing Record 26 of Set 12 | ixtapa
# Processing Record 27 of Set 12 | sanshui
# Processing Record 28 of Set 12 | mostaganem
# Processing Record 29 of Set 12 | kuala belait
# Processing Record 30 of Set 12 | neiafu
# Processing Record 31 of Set 12 | cooma
# Processing Record 32 of Set 12 | poronaysk
# Processing Record 33 of Set 12 | nuwara eliya
# Processing Record 34 of Set 12 | acarau
# Processing Record 35 of Set 12 | port moresby
# Processing Record 36 of Set 12 | sao joao da barra
# Processing Record 37 of Set 12 | bejubang dua
# Processing Record 38 of Set 12 | flin flon
# Processing Record 39 of Set 12 | gao
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.count()
# Out:
# City          590
# Lat           590
# Lng           590
# Max Temp      590
# Humidity      590
# Cloudiness    590
# Wind Speed    590
# Country       590
# Date          590
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        dudinka -35.2813  149.1292     54.28        91         100
# 1  port mathurin -35.2813  149.1292     54.28        91         100
# 2     bredasdorp -35.2813  149.1292     54.28        91         100
# 3        aasiaat -35.2813  149.1292     54.28        91         100
# 4       den burg -35.2813  149.1292     54.28        91         100
#
#    Wind Speed Country        Date
# 0        8.05      AU  1714842633
# 1        8.05      AU  1714842633
# 2        8.05      AU  1714842633
# 3        8.05      AU  1714842633
# 4        8.05      AU  1714842633

# %%
# Read saved data
city_data_df = pd.read_csv("../cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               faya  18.3851   42.4509     22.06        35          21
# 1            farsund  58.0948    6.8047     13.30       100           0
# 2        new norfolk -42.7826  147.0587     11.72        58          12
# 3          jamestown  42.0970  -79.2353      5.77        77         100
# 4            lanzhou  36.0564  103.7922     14.53        48          59
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 2              1.34      AU  1666108230
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
latitude = city_data_df["Lat"]
temperature = city_data_df["Max Temp"]
x_axis = latitude
y_axis = temperature
plt.scatter(x_axis, y_axis, facecolors="lightblue", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature(2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid()

# Save the figure
plt.savefig("Fig1.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity
latitude = city_data_df["Lat"]
humidity = city_data_df["Humidity"]
x_axis = latitude
y_axis = humidity
plt.scatter(x_axis, y_axis, facecolors="lightblue", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

# Save the figure
plt.savefig("Fig3.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness
latitude = city_data_df["Lat"]
cloudiness = city_data_df["Cloudiness"]
x_axis = latitude
y_axis = cloudiness
plt.scatter(x_axis, y_axis, facecolors="lightblue", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("cloudiness(%)")
plt.grid()

# Save the figure
plt.savefig("Fig3.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed
latitude = city_data_df["Lat"]
wind_speed = city_data_df["Wind Speed"]
x_axis = latitude
y_axis = wind_speed
plt.scatter(x_axis, y_axis, facecolors="lightblue", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid()

# Save the figure
plt.savefig("Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
from scipy.stats import linregress
import scipy.stats as st

# %%
# Define a function to create Linear Regression plots
def linear_regression_plot(df, x_col, y_col, title, color="lightblue"):
    x_data = df[x_col]
    y_data = df[y_col]

    linear_regression = linregress(x_data, y_data)
    # print(linear_regression)
    y_regression = x_data * linear_regression.slope + linear_regression.intercept  #mx +b =y (slop=m, b=intercept, x=value)
    # print(y_regression)
    
    plt.scatter(x_data, y_data, facecolors=color, edgecolors="black")
    
    linear_equation = "y = " + str(round(linear_regression.slope,2)) + "x + " + str(round(linear_regression.intercept,2))
    annotation_x = x_data.min()
    annotation_y = y_data.max()
    
    plt.plot(x_data, y_regression, "-", color="red")
    plt.annotate(linear_equation, xy=(annotation_x, annotation_y), color="red")
    plt.xlabel(x_col)
    plt.ylabel(y_col)
    plt.title(title)
    print(f"The r-value is: {linear_regression.rvalue}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             faya  18.3851   42.4509     22.06        35          21
# 1          farsund  58.0948    6.8047     13.30       100           0
# 3        jamestown  42.0970  -79.2353      5.77        77         100
# 4          lanzhou  36.0564  103.7922     14.53        48          59
# 6           albany  42.6001  -73.9662     10.36        74          29
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230
# 6              2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_regression_plot(northern_hemi_df, "Lat", "Max Temp", "Northern Hemisphere: Temperature vs. Latitude", color="lightblue")
# Out:
# The r-value is: -0.8462548186825364

# %%
# Linear regression on Southern Hemisphere
linear_regression_plot(southern_hemi_df, "Lat", "Max Temp", "Southern Hemisphere: Temperature vs. Latitude", color="lightblue")
# Out:
# The r-value is: 0.6419546065421801

# %% [markdown]
# **Discussion about the linear relationship:** The graphs above compare latitude with Temperature. The northern hempisphere has a stronger linear relationship than the southern hemisphere. Both graphs show the closer to the equator the temper increases while further away from the equator the temperature decreases.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression_plot(northern_hemi_df, "Lat", "Humidity", "Northern Hemisphere: Humidity vs. Latitude", color="lightblue")
# Out:
# The r-value is: 0.2385317912939407

# %%
# Southern Hemisphere
linear_regression_plot(southern_hemi_df, "Lat", "Humidity", "Southern Hemisphere: Humidity vs. Latitude", color="lightblue")
# Out:
# The r-value is: 0.016759316950056818

# %% [markdown]
# **Discussion about the linear relationship:** The graphs above compare latitude with humidity. The northern and southern hempisphere do not have a strong linear relationship. The northern hemisphere tends to be more humid further away from the equator while the southern is pretty evenly distributed and latitude does not play much of a factor.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression_plot(northern_hemi_df, "Lat", "Cloudiness", "Northern Hemisphere: Cloudiness vs. Latitudes", color="lightblue")
# Out:
# The r-value is: 0.155004893876971

# %%
# Southern Hemisphere
linear_regression_plot(southern_hemi_df, "Lat", "Cloudiness", "Southern Hemisphere: Cloudiness vs. Latitude", color="lightblue")
# Out:
# The r-value is: 0.14341322916643243

# %% [markdown]
# **Discussion about the linear relationship:** The graphs above compare latitude with cloudiness. The northern and southern hempisphere do not have a strong linear relationship. The northern hemisphere shows the further way from the equator has more cloud coverage while its is the opposit for the southern hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression_plot(northern_hemi_df, "Lat", "Wind Speed", "Northern Hemisphere: Wind Speed vs. Latitude", color="lightblue")
# Out:
# The r-value is: 0.1743466729090334

# %%
# Southern Hemisphere
linear_regression_plot(southern_hemi_df, "Lat", "Wind Speed", "Southern Hemisphere: Wind Speed vs. Latitude", color="lightblue")
# Out:
# The r-value is: -0.24947753546264592

# %% [markdown]
# **Discussion about the linear relationship:** The graphs above compare latitude with wind speed. The northern and the southern hempisphere have a strong linear relationship. The closer to the equator the lower the wind speed while the further away from the equator the higher the wind speed gets.
